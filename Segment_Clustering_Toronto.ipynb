# %%
import pandas as pd
import numpy as np
import urllib.request
# !conda install -c anaconda beautifulsoup4 --yes
from bs4 import BeautifulSoup

# %% [markdown]
# # First step - Getting the data from the wiki

# %% [markdown]
# ## Opening wiki and reading in the needed table

# %%
wikilink='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M' 

wikipage=urllib.request.urlopen(wikilink)

soup=BeautifulSoup(wikipage,features='html.parser')

data_table=soup.find('table', class_ = 'wikitable sortable')

# %% [markdown]
# ## Reading in postcodes, boroughs and neighborhoods

# %%
postcode=[]
borough=[]
neighborhood=[]
for row in data_table.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') 
    if len(cells)==3: 
        postcode.append(cells[0].find(text=True).rstrip())
        borough.append(cells[1].find(text=True).rstrip())
        neighborhood.append(cells[2].find(text=True).rstrip())

# %% [markdown]
# ## Creating dataframe from the wiki data

# %%
df=pd.DataFrame(postcode,columns=['Postcode'])
df['Borough']=borough
df['Neighborhood']=neighborhood

# %% [markdown]
# ## Dropping lines with Not assigned boroughs

# %%
df.replace("Not assigned",np.nan,inplace=True)
df.dropna(subset=['Borough'],axis=0,inplace=True)
df.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## If the neighboor is Not assigned, using the borough instead

# %%
df['Neighborhood'].fillna(df['Borough'], inplace=True)

# %% [markdown]
# ## Grouping boroughs with the same postcodes, using commas as separators

# %%
df_new=df.groupby(['Postcode','Borough'],as_index=False).agg((', '.join))
df_new
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %% [markdown]
# ## Shape of the final dataset

# %%
df_new.shape
# Out:
# (103, 3)

# %% [markdown]
# # Second step - getting the geospatial data, the given package was unreliable, using csv instead

# %% [markdown]
# ## Reading in the csv

# %%
geo_data_path="http://cocl.us/Geospatial_data"
geo_data=pd.read_csv(geo_data_path)

# %% [markdown]
# ## Renaming postal code column to be compatible with the dataset

# %%
geo_data.rename({'Postal Code':'Postcode'},axis=1,inplace=True)

# %% [markdown]
# ## Merging dataset with csv data

# %%
geo_data_new=pd.merge(df_new,geo_data,how='left',on='Postcode')
geo_data_new

# %% [markdown]
# # Third step - visualizing the data on the map

# %%
# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')

# %% [markdown]
# ## Getting the address of Toronto, coordinates, too

# %%
address='Toronto'
geolocator=Nominatim(user_agent="TN_explorer")
location=geolocator.geocode(address)
latitude=location.latitude
longitude=location.longitude
print("The geographic coordinates of Toronto are {},{}:".format(latitude,longitude))

# %% [markdown]
# ## Setting up FourSquare credentials, I deleted my private ones from the final file

# %%
CLIENT_ID = 'XXX' # your Foursquare ID
CLIENT_SECRET = 'XXX' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)

# %% [markdown]
# ## Defining the method to get the venues for a neighborhood

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# ## Getting all the venues from FourSquare

# %%
toronto_venues = getNearbyVenues(names=geo_data_new['Neighborhood'],
                                   latitudes=geo_data_new['Latitude'],
                                   longitudes=geo_data_new['Longitude']
                                  )

# %% [markdown]
# ## Creating one hot coded version

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# ## Creating method to get most common venues

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ## Create a new dataframe and display the top 10 venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()

# %% [markdown]
# ## Doing the clustering

# %%
# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]

# %%
# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

toronto_merged = geo_data_new

toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head()
toronto_merged.dropna(subset=['Cluster Labels'],axis=0,inplace=True)

# %% [markdown]
# ## Displaying the clusters on the map

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]


# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[int(cluster)-1],
        fill=True,
        fill_color=rainbow[int(cluster)-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Cluster one - mainly coffee shops and parks

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels          1st Most Common Venue  \
# 0         Scarborough             0.0           Fast Food Restaurant
# 2         Scarborough             0.0            Rental Car Location
# 3         Scarborough             0.0                    Coffee Shop
# 4         Scarborough             0.0            Fried Chicken Joint
# 5         Scarborough             0.0     Construction & Landscaping
# 6         Scarborough             0.0                 Discount Store
# 7         Scarborough             0.0                       Bus Line
# 8         Scarborough             0.0                          Motel
# 9         Scarborough             0.0          General Entertainment
# 10        Scarborough             0.0              Indian Restaurant
# 11        Scarborough             0.0                 Sandwich Place
# 12        Scarborough             0.0      Latin American Restaurant
# 13        Scarborough             0.0                    Pizza Place
# ...

# %% [markdown]
# ## Cluster two - Garden and no coffee shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough  Cluster Labels 1st Most Common Venue  \
# 63  Central Toronto             1.0                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 63         Women's Store               Dog Run      Department Store
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 63          Dessert Shop    Dim Sum Restaurant                 Diner
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 63        Discount Store      Doner Restaurant           Dance Studio

# %% [markdown]
# ## Cluster three - Bar, stores and no coffee shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#        Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 1  Scarborough             2.0                   Bar         Women's Store
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 1      Department Store          Dessert Shop    Dim Sum Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 1                 Diner        Discount Store               Dog Run
#
#   9th Most Common Venue 10th Most Common Venue
# 1      Doner Restaurant            Event Space

# %% [markdown]
# ## Cluster four - parks and no coffee shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels 1st Most Common Venue  \
# 14        Scarborough             3.0                  Park
# 20         North York             3.0                  Park
# 23         North York             3.0                  Park
# 25         North York             3.0                  Park
# 30         North York             3.0                  Park
# 40          East York             3.0                  Park
# 44    Central Toronto             3.0                  Park
# 50   Downtown Toronto             3.0                  Park
# 64    Central Toronto             3.0                  Park
# 74               York             3.0                  Park
# 90          Etobicoke             3.0                 River
# 100         Etobicoke             3.0                  Park
#
#     2nd Most Common Venue 3rd Most Common Venue        4th Most Common Venue  \
# 14             Playground        Discount Store                 Dance Studio
# ...

# %% [markdown]
# ## Cluster five - resturants, no parks or coffee shops

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 94  Etobicoke             4.0   Filipino Restaurant         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 94      Doner Restaurant      Department Store          Dessert Shop
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 94    Dim Sum Restaurant                 Diner        Discount Store
#
#    9th Most Common Venue 10th Most Common Venue
# 94               Dog Run             Donut Shop
